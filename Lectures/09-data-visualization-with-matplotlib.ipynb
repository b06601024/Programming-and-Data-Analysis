# %% [markdown]
# # Programming and Data Analysis
#
# > Data Visualization with Matplotlib
#
# Kuo, Yao-Jen <yaojenkuo@ntu.edu.tw> from [DATAINPOINT](https://www.datainpoint.com/)

# %% [markdown]
# 一些可以在terminal 裡面執行的comment
# 例如：
# conda env list
# conda activate 環境名字
# clear
# pwd
# cd copy and paste directory

# %%
from datetime import date
from datetime import timedelta
from urllib.error import HTTPError
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## About Matplotlib

# %% [markdown]
# ## What is `matplotlib`?
#
# > Matplotlib, short for matlab plotting library is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# Source: <https://matplotlib.org/>

# %% [markdown]
# ## Import Matplotlib with `import` command
#
# Matplotlib is officially aliased as `mpl`.

# %%
import matplotlib as mpl

# %% [markdown]
# ## If Matplotlib is not installed, we will encounter a `ModuleNotFoundError`
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# ModuleNotFoundError: No module named 'matplotlib'
# ```

# %% [markdown]
# ## Use `pip install` at Terminal to install matplotlib
#
# ```bash
# pip install matplotlib
# ```

# %% [markdown]
# ## Check version and its installation file path
#
# - `__version__` attribute
# - `__file__` attribute

# %%
print(mpl.__version__)
print(mpl.__file__)
# Out:
# 3.3.4
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py

# %% [markdown]
# ## We will use `matplotlib.pyplot` through this chapter, which is a plotting module in matplotlib, officially aliased as `plt`

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Why visualization?
#
# > Visualization plays a vital role among exploratory data analysis. Sometimes it is extremely difficult for human to understand raw data, functions, or formulas.

# %% [markdown]
# ## The abstractness of raw data

# %%
arr = np.random.normal(size=10000)
arr
# Out:
# array([ 0.02512896, -0.41228165,  1.24830458, ..., -0.79865257,
#         0.70862817, -0.10494471])

# %% [markdown]
# ## The abstractness of functions
#
# \begin{equation}
# J(p) = -y_{true}log(p)-(1-y_{true})log(1-p)
# \end{equation}

# %% [markdown]
# ## The abstractness of functions
#
# \begin{equation}
# f(x) = \frac{1}{1 + e^{-x}}
# \end{equation}

# %% [markdown]
# ## The concreteness of visualization for raw data

# %%
fig = plt.figure()
ax = plt.axes()
ax.hist(arr, bins=50)
plt.show()

# %% [markdown]
# ## The concreteness of visualization for functions

# %%
eps = 1e-06 # epsilon, a tiny number to avoid infinity
p = np.linspace(0 + eps, 1 - eps, 10000)
log_loss_0 = -np.log(1-p)
log_loss_1 = -np.log(p)

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(p, log_loss_0, label='$y_{true}=0, -log(1-p)$')
ax.plot(p, log_loss_1, label='$y_{true}=1, -log(p)$')
ax.legend()
plt.show()

# %% [markdown]
# ## The concreteness of visualization for functions

# %%
x = np.linspace(-10, 10, 100)
fx = 1 / (1 + np.exp(-x))
fig = plt.figure()
ax = plt.axes()
ax.plot(x, fx)
plt.show()

# %% [markdown]
# ## The classic visualizations of all time
#
# - [Charles Minard's map of Napoleon's disastrous Russian campaign of 1812](https://en.wikipedia.org/wiki/Charles_Joseph_Minard#/media/File:Minard.png).
# - [Hans Rosling's 200 Countries, 200 Years, 4 Minutes](https://youtu.be/jbkSRLYSojo).

# %% [markdown]
# ## Characteristics of a good visualization
#
# - Informative.
# - Simple.
# - Pretty.

# %% [markdown]
# ## Two ways to plot

# %% [markdown]
# ## The most challenging part for matplotlib newbies is its various plotting syntaxes

# %% [markdown]
# ## There are 2 plotting syntaxes to adapt
#
# - Matlab style.
# - Object-oriented style.

# %% [markdown]
# ## Plotting with matlab style: stateful interface

# %%
x1 = np.linspace(0, np.pi*2, 100)
x2 = np.linspace(np.pi * 0.5, np.pi*2.5, 100)
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x1, np.sin(x1))   
plt.subplot(2, 1, 2)
plt.plot(x2, np.cos(x2))
plt.show()

# %% [markdown]
# ## Plotting with object-oriented style: object method interface

# %%
fig, axes = plt.subplots(2, 1)
axes[0].plot(x1, np.sin(x1))
axes[1].plot(x2, np.cos(x2))
plt.show()

# %% [markdown]
# ## We will adapt the object-oriented style.

# %% [markdown]
# ## The general steps

# %% [markdown]
# ## The general steps to create plots are:
#
# 1. Creating arrays.
# 2. Generating figure and axes objects(respectively or simultaneously).
# 3. Calling various methods of axes object to generate main plot.
# 4. Calling various methods of axes object to add elements.
# 5. Show or save plots.

# %% [markdown]
# ## Creating arrays

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

# %% [markdown]
# ## Generating figure and axes objects respectively

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# ## Generating figure and axes objects simultaneously

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## Calling various methods of axes object to generate main plot

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)

# %% [markdown]
# ## Calling various methods of axes object to add elements

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)
ax.set_title('A simple plot')
ax.set_xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ## Show plots

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)
ax.set_title('A simple plot')
ax.set_xlabel('x')
plt.show()

# %% [markdown]
# ## Save plots
#
# Various format is supported.

# %%
fig = plt.figure()
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)
ax.set_title('A simple plot')
ax.set_xlabel('x')
fig.savefig('a_simple_plot.png')  #副檔名，要看上一個有提供什麼副檔名字

# %% [markdown]
# ## Different methods for different plot types
#
# - `scatter()` for scatter plots.
# - `hist()` for histograms.
# - `plot()` for lines.
# - `bar()` for bar plots.
# - `imshow()` for showing images in `ndarray` format.
# - ...etc.

# %%
def get_latest_daily_report():
    today = date.today()
    day_delta = timedelta(days=1)
    data_date = today
    while True:
        data_date_str = date.strftime(data_date, '%m-%d-%Y')
        print("Try importing {} data...".format(data_date_str))
        daily_report_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{}.csv".format(data_date_str)
        try:
            daily_report = pd.read_csv(daily_report_url)
            print("Successfully imported {} data!".format(data_date_str))
            break
        except HTTPError:
            data_date -= day_delta
    return daily_report

daily_report = get_latest_daily_report()
# Out:
# Try importing 12-21-2021 data...
# Try importing 12-20-2021 data...
# Successfully imported 12-20-2021 data!

# %%
# 看一下資料大概長怎麼樣？
print(type(daily_report))
print(daily_report.columns)
print(daily_report.shape)
print(daily_report.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')
# (4006, 14)
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-12-21 03:21:27  33.93911
# 1   NaN    NaN            NaN        Albania  2021-12-21 03:21:27  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-12-21 03:21:27  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-12-21 03:21:27  42.50630
# 4   NaN    NaN            NaN         Angola  2021-12-21 03:21:27 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     157795    7335        NaN     NaN  Afghanistan
# 1  20.168300     205897    3172        NaN     NaN      Albania
# 2   1.659600     214835    6190        NaN     NaN      Algeria
# 3   1.521800      21062     137        NaN     NaN      Andorra
# 4  17.873900      66086    1738        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     405.347353             4.648436
# 1    7154.666759             1.540576
# 2     489.919932             2.881281
# 3   27259.431826             0.650461
# 4     201.075461             2.629906

# %% [markdown]
# ## `scatter` for scatter plots

# %%
# step 1
x = daily_report["Incident_Rate"].values
y = daily_report["Case_Fatality_Ratio"].values

# step 2
fig = plt.figure()
ax = plt.axes()

#step 3
ax.scatter(x, y, s=1)

#step 4 添加元素
# 這邊跳過


# step 5
plt.show()

# %%
print(type(daily_report))
print(daily_report.columns)
print(daily_report.shape)
print(daily_report.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update',
#        'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio'],
#       dtype='object')
# (4006, 14)
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-12-21 03:21:27  33.93911
# 1   NaN    NaN            NaN        Albania  2021-12-21 03:21:27  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-12-21 03:21:27  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-12-21 03:21:27  42.50630
# 4   NaN    NaN            NaN         Angola  2021-12-21 03:21:27 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered  Active Combined_Key  \
# 0  67.709953     157795    7335        NaN     NaN  Afghanistan
# 1  20.168300     205897    3172        NaN     NaN      Albania
# 2   1.659600     214835    6190        NaN     NaN      Algeria
# 3   1.521800      21062     137        NaN     NaN      Andorra
# 4  17.873900      66086    1738        NaN     NaN       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     405.347353             4.648436
# 1    7154.666759             1.540576
# 2     489.919932             2.881281
# 3   27259.431826             0.650461
# 4     201.075461             2.629906

# %%
x = daily_report["Incident_Rate"].values
print(x)
# Out:
# [ 405.34735349 7154.66675933  489.91993189 ...   33.86981438 1181.01348807
#  1312.52074373]

# %% [markdown]
# ## `hist` for histograms

# %%
# step 1
x = daily_report["Incident_Rate"].values # cases per 100,000 persons

# step 2
fig = plt.figure()
ax = plt.axes()

# step 3
ax.hist(x, bins=50)

# step 5
plt.show()

# %%
def get_confirmed_time_series():
    request_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
    time_series = pd.read_csv(request_url)
    id_cols = time_series.columns[:4]
    time_series_long = pd.melt(time_series, id_vars=id_cols, var_name='Date', value_name='Confirmed')
    date = pd.to_datetime(time_series_long['Date'])
    time_series_long = time_series_long.drop('Date', axis=1)
    time_series_long.insert(4, 'Date', date)
    groupby_series = time_series_long.groupby(['Country/Region', 'Date'])['Confirmed'].sum()
    out = pd.DataFrame(groupby_series).reset_index()
    return out

confirmed_time_series = get_confirmed_time_series()

# %% [markdown]
# ## `plot` for lines

# %%
# step 1 : 先把x軸和y軸準備好
global_ts = confirmed_time_series.groupby("Date")["Confirmed"].sum()

x = global_ts.index
y = global_ts.values

# step 2: 準備軸物件和畫布
fig = plt.figure()
ax = plt.axes()

# step 3 
ax.plot(x, y)

# step 5
plt.show()

# %% [markdown]
# ## `bar` for vertical bar plots

# %%
# step 1
world_top_ten = daily_report.groupby('Country_Region')['Confirmed'].sum().sort_values()[-10:]

x = world_top_ten.index
height = world_top_ten.values

# step2
fig = plt.figure()
ax = plt.axes()

# step 3
ax.bar(x, height)

# step 5
plt.show()

# %% [markdown]
# ## `barh` for horizontal bar plots

# %%
# step 1 
y = world_top_ten.index
width = world_top_ten.values

# step 2
fig = plt.figure()
ax = plt.axes()

# step 3
ax.barh(y, width)

# step 5
plt.show()

# %% [markdown]
# ## Techniques for adding elements

# %% [markdown]
# ## How to add title and axis labels
#
# - `set_title` to add title.
# - `set_xlabel` to add x-axis label.
# - `set_ylabel` to add y-axis label.

# %%
# step 1
y = world_top_ten.index
width = world_top_ten.values

# step 2
fig = plt.figure()
ax = plt.axes()

# step 3
ax.barh(y, width)

# step 4
ax.set_title('The Ten Countries with Most Confirmed Cases.')
ax.set_xlabel('Confirmed')
ax.set_ylabel('Country Name')

# step 5
plt.show()

# %% [markdown]
# ## How to adjust axis ticks 調整軸上的刻度
#
# - `set_xticks` to adjust x-axis ticks.
# - `set_yticks` to adjust y-axis ticks.

# %%
fig = plt.figure()
ax = plt.axes()
y = world_top_ten.index
width = world_top_ten.values
ax.barh(y, width)

# 把刻度都拿掉
ax.set_xticks([])
ax.set_yticks([])


plt.show()

# %%
fig = plt.figure()
ax = plt.axes()
y = world_top_ten.index
width = world_top_ten.values
ax.barh(y, width)


ax.set_xticks([1e7, 2e7, 3e7])
ax.set_yticks([7, 8, 9])


plt.show()

# %% [markdown]
# ## How to adjust axis tick labels 刻度上的標籤
#
# - `set_xticklabels` to adjust x-axis tick labels.
# - `set_yticklabels` to adjust y-axis tick labels.

# %%
fig = plt.figure()
ax = plt.axes()
y = world_top_ten.index
width = world_top_ten.values
ax.barh(y, width)
ax.set_yticks([7, 8, 9])
ax.set_yticklabels(["BRA", "IND", "USA"])
plt.show()

# %% [markdown]
# ## How to adjust axis limits 調整軸的上下限
#
# - `set_xlim` to adjust the upper/lower limits of x-axis.
# - `set_ylim` to adjust the upper/lower limits of y-axis.

# %%
fig = plt.figure()
ax = plt.axes()
y = world_top_ten.index
width = world_top_ten.values
ax.barh(y, width)

ax.set_xlim(0, 1e8)

plt.show()

# %% [markdown]
# ## How to add texts
#
# `text(x, y, 'Some Strings')` to add `'Some Strings'` at (x, y).

# %%
fig = plt.figure()
axes = plt.axes()
axes.barh(world_top_ten.index, world_top_ten.values)

for i in range(world_top_ten.size):
    v = world_top_ten.values[i]
    axes.text(v + 1000000, i - 0.2, "{:,}".format(v))

axes.set_xlim(0, 4.5e7)
plt.show()

# %%
fig = plt.figure()
axes = plt.axes()
axes.barh(world_top_ten.index, world_top_ten.values)

for i in range(world_top_ten.size):
    v = world_top_ten.values[i]
    v_in_million = v / 1e6
    axes.text(v + 1e6, i - 0.15, "{:.1f}M".format(v_in_million))

axes.set_xlim(0, world_top_ten.max() + 2e7)
plt.show()

# %% [markdown]
# ## How to add legends
#
# `lenged()` and `label` parameterto add a legend to indicate categories.

# %%
def plot_lines_with_legends(country_names, ts_df):
    fig = plt.figure()
    ax = plt.axes()
    for country in country_names:
        country_data = ts_df[ts_df['Country/Region'].str.contains(country)]
        x = country_data['Date']
        y = country_data['Confirmed']
        ax.plot(x, y, label=country)
    ax.set_xlabel('Date')
    ax.set_title('Cumulative COVID-19 confirmed cases')
    ax.legend()
    plt.show()

# %%
plot_lines_with_legends(['Taiwan', 'Singapore', 'Malaysia'], confirmed_time_series)

# %% [markdown]
# ## How to solve the problem that matplotlib supporting only English and European fonts?

# %%
fig = plt.figure()
ax = plt.axes()
tw = confirmed_time_series[confirmed_time_series['Country/Region'].str.contains('Taiwan')]
ax.plot(tw['Date'].values, tw['Confirmed'].values, label='台灣')
ax.set_title('COVID-19 累計確診人數')
ax.set_xlabel('日期')
ax.legend()
plt.show()
# Out:
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 32047 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30906 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35386 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25976 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26399 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 28771 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26399 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 32047 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 30906 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35386 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/woohockhynn/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 28771 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Calling `FontProperties` function from `matplotlib.font_manager`

# %%
from matplotlib.font_manager import FontProperties

my_font = FontProperties(fname="/System/Library/Fonts/STHeiti Light.ttc") # Specify a font supporting Chinese

# %%
fig = plt.figure()
ax = plt.axes()
tw = confirmed_time_series[confirmed_time_series['Country/Region'].str.contains('Taiwan')]
ax.plot(tw['Date'].values, tw['Confirmed'].values, label='台灣')
ax.set_title('COVID-19 累計確診人數', fontproperties=my_font)
ax.set_xlabel('日期', fontproperties=my_font)
ax.legend(prop=my_font)
plt.show()

# %% [markdown]
# ## How to create a subplot grid?
#
# - `subplots(m, n)` to create a `ndarray` with a shape `(m, n)`.
# - There are (m, n) axes objects inside the `ndarray`.
# - Access axes objects through `[m, n]`.

# %%
fig, axes = plt.subplots(2,3)
print(type(axes))
print(axes.shape)
# Out:
# <class 'numpy.ndarray'>
# (2, 3)

# %%
x1 = np.linspace(0, 2*np.pi, 100)
x2 = np.linspace(0.5*np.pi, 2.5*np.pi, 100)
y_sin = np.sin(x1)
y_cos = np.cos(x2)
fig, axes = plt.subplots(2, 3)
axes[0, 1].plot(x1, y_sin)
axes[1, 2].plot(x2, y_cos)
plt.show()
